# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
def make_timedelta(df):
    df['seconds'] = df['time']
    df['time'] = pd.to_timedelta(df['time'], unit='s')
    return df

def get_highest_accuracy(df):
    highest_accuracy = pd.DataFrame(columns=df.columns)
   
    i = 0
    for er in np.unique(df["error-rate"]):
        highest_accuracy.loc[i] = list(df[df["matches"] == np.max(df[df["error-rate"] == er]["matches"])].iloc[0])
        i = i + 1
    
    return highest_accuracy

# %% [markdown]
# # Mouse vs fly reference genomes
#
# min_len = 150

# %% [markdown]
# ## Stellar

# %%
stellar_time = pd.read_csv("stellar_mouse.time", sep = "\t")
make_timedelta(stellar_time)
# Out:
#                      time       mem  error-code         command  min-len  \
# 0         0 days 02:08:42  10005920           0  stellar-search      150
# 1  0 days 00:17:04.210000  11743712           0  stellar-search      150
# 2  0 days 01:33:19.200000  11760372           0  stellar-search      150
# 3  0 days 15:31:19.830000  11901144           0  stellar-search      150
# 4  0 days 15:40:35.630000  10417456           0  stellar-search      150
# ..                    ...       ...         ...             ...      ...
# 68 0 days 15:35:34.640000  11913552           0  stellar-search      150
# 69 0 days 04:37:33.210000  11822848           0  stellar-search      150
# 70 0 days 12:04:42.180000  11909232           0  stellar-search      150
# 71 0 days 00:01:41.250000  11518604          11  stellar-search      150
# 72        0 days 05:54:41  10249832           0  stellar-search      150
#
#     error-rate  repeat-period  repeat-length   seconds
# 0       0.0267              1           1000   7722.00
# 1       0.0330              4             25   1024.21
# 2       0.0267              4             50   5599.20
# 3       0.0400              2            100  55879.83
# 4       0.0400              1             50  56435.63
# ..         ...            ...            ...       ...
# 68      0.0400              4           1000  56134.64
# 69      0.0330              2             50  16653.21
# 70      0.0400              2             50  43482.18
# 71      0.0130              4            100    101.25
# 72      0.0330              1             25  21281.00
#
# [73 rows x 9 columns]

# %%
stellar_matches = pd.read_csv("stellar_match_count.tsv", sep = "\t")
#stellar_matches.head()

# %%
stellar_mouse = pd.merge(stellar_time, stellar_matches, how="left", on=["error-rate", "repeat-period", "repeat-length", "min-len"])
#stellar_mouse.head()

# %%
failed_runs = stellar_mouse[(stellar_mouse["error-code"] != 0) & (stellar_mouse["matches"] > 0)].index
stellar_mouse.drop(failed_runs, inplace = True)

# %%
wrong_error_code = stellar_mouse[(stellar_mouse["error-code"] == 0) & (stellar_mouse["matches"] == 0)].index
stellar_mouse.drop(wrong_error_code, inplace = True)

# %%
stellar_mouse = stellar_mouse[stellar_mouse["error-code"] == 0]
error_rates = np.unique(stellar_mouse["error-rate"])
stellar_mouse.head()
# Out:
#                     time       mem  error-code         command  min-len  \
# 0        0 days 02:08:42  10005920           0  stellar-search      150
# 1 0 days 00:17:04.210000  11743712           0  stellar-search      150
# 2 0 days 01:33:19.200000  11760372           0  stellar-search      150
# 4 0 days 15:40:35.630000  10417456           0  stellar-search      150
# 5 0 days 00:15:07.040000  11697420           0  stellar-search      150
#
#    error-rate  repeat-period  repeat-length   seconds  matches
# 0      0.0267              1           1000   7722.00   103208
# 1      0.0330              4             25   1024.21    91899
# 2      0.0267              4             50   5599.20    88661
# 4      0.0400              1             50  56435.63   160137
# 5      0.0267              4             25    907.04    65347

# %%
for er in error_rates:
    er_rate_runs = stellar_mouse[stellar_mouse["error-rate"] == er]
    print(er)
    print("Corr repeat-period\t" + str(er_rate_runs["repeat-period"].corr(er_rate_runs["matches"])))
    print("Corr repeat-length\t" + str(er_rate_runs["repeat-length"].corr(er_rate_runs["matches"])))
    print("Corr time\t" + str(er_rate_runs["time"].corr(er_rate_runs["matches"])))
# Out:
# 0.0267
# Corr repeat-period	-0.5749652444761867
# Corr repeat-length	0.2869991179202832
# Corr time	0.6783328354499112
# 0.033
# Corr repeat-period	-0.5188064722046153
# Corr repeat-length	0.26764405714678297
# Corr time	0.7731811961995414
# 0.04
# Corr repeat-period	-0.4415139176838639
# Corr repeat-length	0.23558846650590795
# Corr time	0.6670797876432318

# %%
stellar_default = stellar_mouse[(stellar_mouse["repeat-period"] == 1) & (stellar_mouse["repeat-length"] == 1000)]
stellar_default
# Out:
#                      time       mem  error-code         command  min-len  \
# 0         0 days 02:08:42  10005920           0  stellar-search      150
# 6  0 days 06:07:46.030000  10307376           0  stellar-search      150
# 43 0 days 15:30:48.120000  10419560           0  stellar-search      150
#
#     error-rate  repeat-period  repeat-length   seconds  matches
# 0       0.0267              1           1000   7722.00   103208
# 6       0.0330              1           1000  22066.03   119991
# 43      0.0400              1           1000  55848.12   160137

# %%
stellar_mouse[stellar_mouse["error-rate"] < 0.04]
# Out:
#                      time       mem  error-code         command  min-len  \
# 0         0 days 02:08:42  10005920           0  stellar-search      150
# 1  0 days 00:17:04.210000  11743712           0  stellar-search      150
# 2  0 days 01:33:19.200000  11760372           0  stellar-search      150
# 5  0 days 00:15:07.040000  11697420           0  stellar-search      150
# 6  0 days 06:07:46.030000  10307376           0  stellar-search      150
# 8  0 days 02:07:01.320000  11734356           0  stellar-search      150
# 10 0 days 06:07:39.110000  11836940           0  stellar-search      150
# 11 0 days 01:33:22.640000  11764224           0  stellar-search      150
# 12 0 days 06:07:32.750000  10295500           0  stellar-search      150
# 13 0 days 02:09:45.440000  11791284           0  stellar-search      150
# 37 0 days 06:07:06.930000  10278688           0  stellar-search      150
# 40 0 days 02:04:38.160000  10010436           0  stellar-search      150
# 42 0 days 00:30:56.250000  11807940           0  stellar-search      150
# 46 0 days 02:06:39.850000  11729160           0  stellar-search      150
# 51 0 days 01:35:05.840000  11728128           0  stellar-search      150
# 52 0 days 06:11:57.680000  11829884           0  stellar-search      150
# 53 0 days 04:34:27.820000  11842176           0  stellar-search      150
# 54 0 days 00:25:06.880000  11690012           0  stellar-search      150
# 57 0 days 06:10:22.040000  11825504           0  stellar-search      150
# 58 0 days 02:05:56.360000  10011380           0  stellar-search      150
# 60 0 days 06:07:57.930000  11836916           0  stellar-search      150
# 62 0 days 02:05:34.080000  10009160           0  stellar-search      150
# 64 0 days 00:16:55.840000  11743956           0  stellar-search      150
# 67 0 days 02:09:40.190000  11737852           0  stellar-search      150
# 69 0 days 04:37:33.210000  11822848           0  stellar-search      150
# 72        0 days 05:54:41  10249832           0  stellar-search      150
#
#     error-rate  repeat-period  repeat-length   seconds  matches
# 0       0.0267              1           1000   7722.00   103208
# 1       0.0330              4             25   1024.21    91899
# 2       0.0267              4             50   5599.20    88661
# 5       0.0267              4             25    907.04    65347
# 6       0.0330              1           1000  22066.03   119991
# 8       0.0267              2           1000   7621.32   103208
# 10      0.0330              2            100  22059.11   119991
# 11      0.0267              4             50   5602.64    88661
# 12      0.0330              1            100  22052.75   119991
# 13      0.0267              4            100   7785.44   103207
# 37      0.0330              1             50  22026.93   119991
# 40      0.0267              1             25   7478.16   103208
# 42      0.0330              2             25   1856.25   119990
# 46      0.0267              2            100   7599.85   103208
# 51      0.0267              2             50   5705.84   103208
# 52      0.0330              4           1000  22317.68   119991
# 53      0.0330              4             50  16467.82   119480
# 54      0.0267              2             25   1506.88   103208
# 57      0.0330              4            100  22222.04   119991
# 58      0.0267              1            100   7556.36   103208
# 60      0.0330              2           1000  22077.93   119991
# 62      0.0267              1             50   7534.08   103208
# 64      0.0330              4             25   1015.84    91899
# 67      0.0267              4           1000   7780.19   103208
# 69      0.0330              2             50  16653.21   119991
# 72      0.0330              1             25  21281.00   119991

# %%
stellar_true_matches = stellar_default[["error-rate", "matches"]] 
stellar_true_matches.columns = ["error-rate", "stellar-matches"]
stellar_true_matches
# Out:
#     error-rate  stellar-matches
# 0       0.0267           103208
# 6       0.0330           119991
# 43      0.0400           160137

# %% [markdown]
# ## Blast

# %%
print(error_rates)
# Out:
# [0.0267 0.033  0.04  ]

# %%
min_len = 150
kmer_list = []
error_list = [0.0067, 0.013, 0.02, 0.0267, 0.033, 0.04, 0.0467, 0.053]
for er in error_list:
    errors = int(round(er * min_len))
    for k in range(51, 6, -1):
        if ((min_len - k + 1 - errors * k) > 2):
            kmer_list.append(k) 
            break
            
d = {'k': kmer_list, 'error-rate': error_list}            
error_df = pd.DataFrame(data=d)
print(error_df)
# Out:
#     k  error-rate
# 0  51      0.0067
# 1  49      0.0130
# 2  37      0.0200
# 3  29      0.0267
# 4  24      0.0330
# 5  21      0.0400
# 6  18      0.0467
# 7  16      0.0530

# %%
blast_time = pd.read_csv("blast_mouse.time", sep = "\t")
blast_time = blast_time[blast_time["command"] == "blast-search"]
blast_time.threads = blast_time.threads.astype(int)
blast_time.k = blast_time.k.astype(int)
blast_time.drop("matches", axis = 1, inplace = True)
make_timedelta(blast_time)
blast_time.head()
# Out:
#                     time      mem  error-code       command  threads  evalue  \
# 1 0 days 00:01:05.580000  1032700           0  blast-search        8   10.00
# 2 0 days 00:02:56.420000  1761172           0  blast-search        8    0.10
# 3 0 days 00:01:20.390000  1126004           0  blast-search        8    0.01
# 4 0 days 00:04:49.190000  2274744           0  blast-search        8   10.00
# 5 0 days 00:10:43.640000  2055048           0  blast-search        8    0.01
#
#     k  seconds
# 1  49    65.58
# 2  21   176.42
# 3  37    80.39
# 4  18   289.19
# 5  16   643.64

# %%
blast_matches = pd.read_csv("blast_mouse_match_count.tsv", sep = "\t")
blast_matches.head()
# Out:
#    evalue   k  matches
# 0   10.00  16   280930
# 1    0.10  51      690
# 2    0.01  21    12096
# 3    1.00  21    43121
# 4    1.00  28    13536

# %%
blast_mouse = pd.merge(blast_time, blast_matches, how="left", on=["evalue", "k"])
blast_mouse = pd.merge(blast_mouse, error_df, how="left", on = ["k"])
blast_mouse = pd.merge(blast_mouse, stellar_true_matches, how="left", on = ["error-rate"])
blast_mouse['stellar-matches'] = blast_mouse['stellar-matches'].fillna(0).astype(int)
blast_mouse.head()
# Out:
#                     time      mem  error-code       command  threads  evalue  \
# 0 0 days 00:01:05.580000  1032700           0  blast-search        8   10.00
# 1 0 days 00:02:56.420000  1761172           0  blast-search        8    0.10
# 2 0 days 00:01:20.390000  1126004           0  blast-search        8    0.01
# 3 0 days 00:04:49.190000  2274744           0  blast-search        8   10.00
# 4 0 days 00:10:43.640000  2055048           0  blast-search        8    0.01
#
#     k  seconds  matches  error-rate  stellar-matches
# 0  49    65.58      809      0.0130                0
# 1  21   176.42    17607      0.0400           160137
# 2  37    80.39     1779      0.0200                0
# 3  18   289.19   185203      0.0467                0
# 4  16   643.64    27491      0.0530                0

# %%
len(blast_mouse[(blast_mouse["error-code"] != 0) & (blast_mouse["matches"] > 0)]) == 0
# Out:
# True

# %%
len(blast_mouse[(blast_mouse["error-code"] == 0) & (blast_mouse["matches"] == 0)]) == 0
# Out:
# True

# %%
blast_mouse[blast_mouse["evalue"] == 10]
# Out:
#                      time      mem  error-code       command  threads  evalue  \
# 0  0 days 00:01:05.580000  1032700           0  blast-search        8    10.0
# 3  0 days 00:04:49.190000  2274744           0  blast-search        8    10.0
# 7  0 days 00:01:20.070000  1101496           0  blast-search        8    10.0
# 10 0 days 00:11:06.390000  2360136           0  blast-search        8    10.0
# 15 0 days 00:02:23.540000  2112456           0  blast-search        8    10.0
# 16 0 days 00:03:03.470000  2185612           0  blast-search        8    10.0
# 25 0 days 00:01:43.830000  1421192           0  blast-search        8    10.0
# 29 0 days 00:00:59.500000  1027924           0  blast-search        8    10.0
# 32 0 days 00:01:15.670000  1128268           0  blast-search       16    10.0
# 34 0 days 00:03:34.620000  3231520           0  blast-search       16    10.0
# 39 0 days 00:01:02.700000  1253180           0  blast-search       16    10.0
# 41 0 days 00:08:22.890000  3413984           0  blast-search       16    10.0
# 47 0 days 00:01:53.660000  3069380           0  blast-search       16    10.0
# 52        0 days 00:02:13  3155812           0  blast-search       16    10.0
# 57 0 days 00:01:25.490000  1809640           0  blast-search       16    10.0
# 61 0 days 00:00:55.340000  1081980           0  blast-search       16    10.0
#
#      k  seconds  matches  error-rate  stellar-matches
# 0   49    65.58      809      0.0130                0
# 3   18   289.19   185203      0.0467                0
# 7   37    80.07     1779      0.0200                0
# 10  16   666.39   280930      0.0530                0
# 15  24   143.54    44886      0.0330           119991
# 16  21   183.47   101422      0.0400           160137
# 25  29   103.83    14515      0.0267           103208
# 29  51    59.50      690      0.0067                0
# 32  49    75.67      809      0.0130                0
# 34  18   214.62   185203      0.0467                0
# 39  37    62.70     1779      0.0200                0
# 41  16   502.89   280930      0.0530                0
# 47  24   113.66    44886      0.0330           119991
# 52  21   133.00   101422      0.0400           160137
# 57  29    85.49    14515      0.0267           103208
# 61  51    55.34      690      0.0067                0

# %%
blast_mouse
# Out:
#                      time      mem  error-code       command  threads  evalue  \
# 0  0 days 00:01:05.580000  1032700           0  blast-search        8   10.00
# 1  0 days 00:02:56.420000  1761172           0  blast-search        8    0.10
# 2  0 days 00:01:20.390000  1126004           0  blast-search        8    0.01
# 3  0 days 00:04:49.190000  2274744           0  blast-search        8   10.00
# 4  0 days 00:10:43.640000  2055048           0  blast-search        8    0.01
# ..                    ...      ...         ...           ...      ...     ...
# 59 0 days 00:02:39.610000  2854188           0  blast-search       16    1.00
# 60 0 days 00:00:56.590000  1092388           0  blast-search       16    1.00
# 61 0 days 00:00:55.340000  1081980           0  blast-search       16   10.00
# 62 0 days 00:03:12.790000  3029936           0  blast-search       16    1.00
# 63 0 days 00:00:52.030000  1093224           0  blast-search       16    0.01
#
#      k  seconds  matches  error-rate  stellar-matches
# 0   49    65.58      809      0.0130                0
# 1   21   176.42    17607      0.0400           160137
# 2   37    80.39     1779      0.0200                0
# 3   18   289.19   185203      0.0467                0
# 4   16   643.64    27491      0.0530                0
# ..  ..      ...      ...         ...              ...
# 59  21   159.61    43121      0.0400           160137
# 60  51    56.59      690      0.0067                0
# 61  51    55.34      690      0.0067                0
# 62  18   192.79    72101      0.0467                0
# 63  51    52.03      690      0.0067                0
#
# [64 rows x 11 columns]

# %% [markdown]
# ## DREAM-Stellar

# %%
dream_entropy_max_er_time = pd.read_csv("error_rates/entropy/search_valik_max_er.time", sep = "\t")
dream_entropy_max_er_time["repeat-mask"] = "entropy"
#dream_entropy_max_er_time.head()

# %%
dream_entropy_time = pd.read_csv("error_rates/entropy/search_valik.time", sep = "\t")
dream_entropy_time.drop("matches", axis = 1, inplace = True)
#dream_entropy_time.head()

# %%
dream_same = dream_entropy_time.drop(["time", "mem", "repeats"], axis = 1)
print(len(dream_same))
dream_same.drop_duplicates()
print(len(dream_same))
# Out:
# 86
# 86

# %%
dream_entropy_matches = pd.read_csv("error_rates/entropy/valik_mouse_match_count.tsv", sep = "\t")
dream_entropy_matches = dream_entropy_matches[dream_entropy_matches["repeat-period"] == 1]
dream_entropy_matches = dream_entropy_matches[dream_entropy_matches["repeat-length"] == 1000]
#dream_entropy_matches.head()

# %%
dream_entropy_mouse = pd.merge(dream_entropy_time, dream_entropy_matches, how="left", on=["bins", "cmax", "error-rate", "bin-entropy-cutoff", "max-carts"])
dream_entropy_mouse["repeat-mask"] = "entropy"
#dream_entropy_mouse.head()

# %%
dream_pattern_count_mouse = pd.read_csv("error_rates/pattern_count/search_valik.time", sep = "\t")
dream_pattern_count_mouse["repeat-mask"] = "pattern-count"
#dream_pattern_count_mouse.head()

# %%
dream_mouse = pd.concat([dream_entropy_mouse, dream_pattern_count_mouse, dream_entropy_max_er_time])
dream_mouse.drop(["fpr", "minimiser", "repeat-flag", "repeat-period", "repeat-length", "cmin"], axis = 1, inplace = True)
dream_mouse['repeats'] = dream_mouse['repeats'].fillna(0).astype(int)
dream_mouse['matches'] = dream_mouse['matches'].fillna(0).astype(int)
make_timedelta(dream_mouse)
dream_mouse.head()
# Out:
#                     time        mem  error-code       command  bins  max-er  \
# 0 0 days 00:02:08.300000   17004320           0  valik-search  1024   0.053
# 1 0 days 00:00:50.710000   13476048           0  valik-search  1024   0.053
# 2 0 days 00:02:51.960000   16882712           0  valik-search  1024   0.053
# 3 0 days 00:00:43.770000   13307064           0  valik-search  1024   0.053
# 4 0 days 00:07:45.850000  318329224           6  valik-search  1024   0.053
#
#    min-len  threads  cmax  error-rate  bin-entropy-cutoff  cart-max-cap  \
# 0      150       32   254      0.0267                0.75         20000
# 1      150       32   254      0.0130                0.75         20000
# 2      150       32   254      0.0330                0.75         20000
# 3      150       32   254      0.0067                0.75         20000
# 4      150       32   254      0.0530                0.75         20000
#
#    max-carts  repeats  matches repeat-mask  kmer-size  seconds
# 0       1024      236    72657     entropy        NaN   128.30
# 1       1024       97    30809     entropy        NaN    50.71
# 2       1024      236    87220     entropy        NaN   171.96
# 3       1024       97    21851     entropy        NaN    43.77
# 4       1024        0        0     entropy        NaN   465.85

# %%
dream_mouse[(dream_mouse["error-rate"] == 0.053) & (dream_mouse["error-code"] != 0)]
# Out:
#                      time        mem  error-code       command  bins  max-er  \
# 4  0 days 00:07:45.850000  318329224           6  valik-search  1024   0.053
# 9  0 days 00:40:31.760000  273042760           6  valik-search  2048   0.053
# 12 0 days 00:08:21.510000  236233252           6  valik-search  1024   0.053
# 19 0 days 00:17:50.990000  233642624           6  valik-search  1024   0.053
# 74 0 days 00:10:21.630000  236061552           6  valik-search  1024   0.053
# 83 0 days 00:54:11.540000  319431016           6  valik-search  1024   0.053
# 7  0 days 00:06:44.940000  220438820           6  valik-search  1024   0.053
# 13 0 days 00:52:34.510000  216128944           6  valik-search  2048   0.053
# 0  0 days 00:08:54.040000  317342152           6  valik-search  1024   0.053
#
#     min-len  threads  cmax  error-rate  bin-entropy-cutoff  cart-max-cap  \
# 4       150       32   254       0.053                0.75         20000
# 9       150       32   254       0.053                0.25         20000
# 12      150       32   254       0.053                0.10         20000
# 19      150       32   150       0.053                0.10         20000
# 74      150       32   254       0.053                0.10         20000
# 83      150       32   254       0.053                0.75         20000
# 7       150       64   254       0.053                 NaN         20000
# 13      150       32   254       0.053                 NaN         20000
# 0       150       32   254       0.053                0.75         20000
#
#     max-carts  repeats  matches    repeat-mask  kmer-size  seconds
# 4        1024        0        0        entropy        NaN   465.85
# 9        1024        0        0        entropy        NaN  2431.76
# 12       4096        0    38307        entropy        NaN   501.51
# 19       4096        0    38316        entropy        NaN  1070.99
# 74       2048        0        0        entropy        NaN   621.63
# 83       1024        0        0        entropy        NaN  3251.54
# 7        1024        0        0  pattern-count       16.0   404.94
# 13       2048        0        0  pattern-count       15.0  3154.51
# 0        2048        0        0        entropy        NaN   534.04

# %%
dream_mouse = pd.merge(dream_mouse, stellar_true_matches, how="left", on = ["error-rate"])
dream_mouse["stellar-matches"] = dream_mouse['stellar-matches'].fillna(0).astype(int)

# %%
np.mean(dream_mouse[(dream_mouse["error-rate"] == 0.02) & (dream_mouse["bins"] == 2048) & (dream_mouse["threads"] == 32)]["matches"])
# Out:
# 26114.75

# %%
get_highest_accuracy(dream_mouse)
# Out:
#                     time        mem  error-code       command  bins  max-er  \
# 0 0 days 00:00:31.180000   11811916           0  valik-search  1024  0.0067
# 1 0 days 00:00:35.650000   11869628           0  valik-search  1024  0.0130
# 2 0 days 00:00:52.140000   12687384           0  valik-search  1024  0.0200
# 3 0 days 00:01:25.360000   13771276           0  valik-search  1024  0.0267
# 4 0 days 00:01:36.760000   13682624           0  valik-search  1024  0.0330
# 5 0 days 00:02:48.900000   15561524           0  valik-search  1024  0.0400
# 6 0 days 01:21:27.780000  318939592           0  valik-search  1024  0.0467
# 7 0 days 00:28:21.250000  185189236           0  valik-search  4096  0.0530
#
#    min-len  threads  cmax  error-rate  bin-entropy-cutoff  cart-max-cap  \
# 0      150       32   254      0.0067                0.75         20000
# 1      150       32   254      0.0130                0.75         20000
# 2      150       32   254      0.0200                0.75         20000
# 3      150       32   254      0.0267                0.75         20000
# 4      150       32   254      0.0330                0.75         20000
# 5      150       32   254      0.0400                0.75         20000
# 6      150       32   254      0.0467                0.75         20000
# 7      150       32   150      0.0530                0.10         20000
#
#    max-carts  repeats  matches repeat-mask  kmer-size  seconds  \
# 0       2048       45    22927     entropy        NaN    31.18
# 1       2048       45    32001     entropy        NaN    35.65
# 2       2048       54    53067     entropy        NaN    52.14
# 3       2048       76    74376     entropy        NaN    85.36
# 4       2048       76    88682     entropy        NaN    96.76
# 5       2048      139   122960     entropy        NaN   168.90
# 6       2048    12151   144958     entropy        NaN  4887.78
# 7       4096     5791    48505     entropy        NaN  1701.25
#
#    stellar-matches
# 0                0
# 1                0
# 2                0
# 3           103208
# 4           119991
# 5           160137
# 6                0
# 7                0

# %% [markdown]
# # Human vs mouse reference genomes

# %% [markdown]
# ## Blast

# %%
blast_human = pd.read_csv("blast_human.time", sep = "\t")
blast_human = blast_human[(blast_human["error-code"] == 0) & (blast_human["command"] == "blast-search")]
blast_human.k = blast_human.k.astype(int)
blast_human.matches = blast_human.matches.astype(int)
blast_human.head()

# %%
len(blast_mouse[(blast_mouse["error-code"] != 0) & (blast_mouse["matches"] > 0)]) == 0

# %%
len(blast_mouse[(blast_mouse["error-code"] == 0) & (blast_mouse["matches"] == 0)]) == 0

# %% [markdown]
# ## DREAM-Stellar

# %%
dream_time = pd.read_csv("dream_human.time", sep = "\t")
#dream_time = pd.concat(dream_low_err_time)
dream_time = dream_time[dream_time["error-code"] == 0]
dream_time.head()

# %%
dream_time["error-rate"]

# %%
dream_low_err_time = pd.read_csv("dream_e0.013_human.time", sep = '\t')
dream_low_err_time.head()
dream_low_err_time["matches"] / dream_low_err_time["time"]

# %%
dream_low_err_time
